# %% [markdown]
# # This tutorial is running on Geforce GTX 1080Ti 12GB

# %% [markdown]
# ## Load Basic Library

# %%
import math
import numpy as np
import tensorflow as tf

# %% [markdown]
# ## Set Environment and Parameters

# %%
import os
os.environ['CUDA_VISIBLE_DEVICES'] = '0' # use first GPU

seed = 2 # random seed
model_dir = "model_CGAN/" # folder for saving model and log
BATCH_SIZE = 1024 # number of images in one batch
NOISE_DIM = 100 # noise dimension for generator
EPOCHS = 50
SAVE_SUMMARY_STEPS = 50 # save summary to tensorboard - one step means one batch
NUM_GPUS = 1 # number of GPU

# %% [markdown]
# ## Load Data
# Use MNIST dataset

# %%
(image, label),(_, _)  = tf.keras.datasets.mnist.load_data()
image = np.expand_dims(image, axis=-1)
label = np.expand_dims(label, axis=-1)
print("Image shape:", image.shape)
print("Label shape:", label.shape)
# Out:
# Image shape: (60000, 28, 28, 1)
# Label shape: (60000, 1)

# %% [markdown]
# ## Feed Training Data to Model

# %%
def train_input_fn(images, labels):
    
    def make_generator(images, labels):

        def _generator():
            for image, label in zip(images, labels):
                yield image, label

        return _generator
    
    # Normalize the values of the image from [0, 255] to [-1.0, 1.0]
    def _preprocessing(image, label):
        image = image * (2.0 / 255.0) - 1.0
        return image, label
    
    dataset = tf.data.Dataset.from_generator(make_generator(images, labels), (tf.float32, tf.float32))
    dataset = dataset.shuffle(buffer_size=10000)
    dataset = dataset.repeat(EPOCHS)
    dataset = dataset.map(_preprocessing)
    dataset = dataset.batch(BATCH_SIZE, drop_remainder=True)
    dataset = dataset.prefetch(None)
    
    iterator = dataset.make_one_shot_iterator()
    
    images, labels = iterator.get_next()
    images = tf.reshape(images, [-1, 28, 28, 1])
    labels = tf.reshape(labels, [-1, 1])
    print("output image:", images.shape)
    print("output label:", labels.shape)
    
    tf.summary.image("images", images)
    
    random_noises = tf.random_normal(shape=(BATCH_SIZE, NOISE_DIM))
    
    features = {"images" : images,
                "random_noises" : random_noises}
    
    return features, labels

# %% [markdown]
# ## Feed Random Noise Data to Model for Eval and Prediction

# %%
def random_noise_input_fn():
    
    np.random.seed(seed)
    
    labels = np.array([[i] for i in range(10)], dtype=np.float32)
    
    dataset = tf.data.Dataset.from_tensors(tf.constant(np.random.randn(10, NOISE_DIM), dtype=tf.float32))
    
    iterator = dataset.make_one_shot_iterator()
    
    noises = iterator.get_next()
    
    return {"random_noises": noises, "labels": labels}, labels

# %% [markdown]
# ## Model Structure
# **Remember: Do batch normalization in training mode, but not in evaluation and prediction mode**
# This model Structure based on DCGAN

# %%
def generator(vectors, labels, training):
    
    with tf.variable_scope("generator", reuse=tf.AUTO_REUSE):
        vectors = tf.concat([vectors, labels], axis=-1)
        with tf.variable_scope("block1"):
            vectors = tf.layers.dense(vectors, units=1024, name="dense")
            vectors = tf.layers.batch_normalization(vectors, training=training, name="batch_normalization")
            vectors = tf.nn.leaky_relu(vectors, alpha=0.2, name="leaky_relu")
        with tf.variable_scope("block2"):
            vectors = tf.layers.dense(vectors, units=7*7*128, name="dense")
            vectors = tf.layers.batch_normalization(vectors, training=training, name="batch_normalization")
            vectors = tf.nn.leaky_relu(vectors, alpha=0.2, name="leaky_relu")
        images = tf.reshape(vectors, [-1, 7, 7, 128])
        with tf.variable_scope("block3"):
            images = tf.layers.conv2d_transpose(images, filters=64, kernel_size=(4, 4), strides=(2, 2), padding="same", name="deconv")
            images = tf.layers.batch_normalization(images, training=training, name="batch_normalization")
            images = tf.nn.leaky_relu(images, alpha=0.2, name="leaky_relu")
        with tf.variable_scope("output"):
            images = tf.layers.conv2d_transpose(images, filters=1, kernel_size=(4, 4), strides=(2, 2), padding="same", name="deconv")
            images = tf.nn.tanh(images, name="tanh")
            
        return images
    
def discriminator(images, labels, training):
    
    with tf.variable_scope("discriminator", reuse=tf.AUTO_REUSE):
        images = tf.concat([images, labels], axis=-1)
        with tf.variable_scope("block1"):
            images = tf.layers.conv2d(images, filters=64, kernel_size=(4, 4), strides=(2, 2), padding="same", name="conv")
            images = tf.layers.batch_normalization(images, training=training, name="batch_normalization")
            images = tf.nn.leaky_relu(images, alpha=0.2, name="leaky_relu")
        with tf.variable_scope("block2"):
            images = tf.layers.conv2d(images, filters=128, kernel_size=(4, 4), strides=(2, 2), padding="same", name="conv")
            images = tf.layers.batch_normalization(images, training=training, name="batch_normalization")
            images = tf.nn.leaky_relu(images, alpha=0.2, name="leaky_relu")
        vectors = tf.layers.flatten(images, name="flatten")
        with tf.variable_scope("block3"):
            vectors = tf.layers.dense(vectors, units=1024, name="dense")
            vectors = tf.layers.batch_normalization(vectors, training=training, name="batch_normalization")
            vectors = tf.nn.leaky_relu(vectors, alpha=0.2, name="leaky_relu")
        with tf.variable_scope("output"):
            values = tf.layers.dense(vectors, units=1, name="dense")
    return values

# %% [markdown]
# ## Model Function for tf.Estimator
# To save model for tensorflow serving, set **`export_outputs`** parameter in prediction mode
# **Note: Learing rate should decay, otherwise the result is not well for some numbers. Like 8**

# %%
def model_fn(features, labels, mode):
    
    if mode == tf.estimator.ModeKeys.TRAIN:
        training = True
    else:
        training = False
    
    # for prediction, when calling predict, tensorflow get features but not get labels
    # So, we should pass labels in features
    labels = features.get("labels", labels)
    
    fake_images = generator(features["random_noises"], labels, training)
    
    # Prediction mode for tensorflow serving
    if mode == tf.estimator.ModeKeys.PREDICT:
        predictions = {
            "images": fake_images
        }
        return tf.estimator.EstimatorSpec(mode=mode, predictions=predictions, export_outputs={ 
            'output': tf.estimator.export.PredictOutput(predictions)})
    
    discriminator_labels = tf.multiply(tf.expand_dims(tf.expand_dims(labels, axis=-1), axis=-1), tf.ones([features["random_noises"].shape[0], 28, 28, 1]))
    fake_values = discriminator(fake_images, discriminator_labels, training)
    
    # calculate cross entropy loss   
    discriminator_fake_loss = tf.losses.sigmoid_cross_entropy(multi_class_labels=tf.zeros_like(fake_values), logits=fake_values, scope="discriminator_fake_loss")
    generator_loss = tf.losses.sigmoid_cross_entropy(multi_class_labels=tf.ones_like(fake_values), logits=fake_values, scope="generator_loss")
    
    if mode == tf.estimator.ModeKeys.TRAIN:
        
        real_images = features["images"]
        real_values = discriminator(real_images, discriminator_labels, training)
        
        discriminator_real_loss = tf.losses.sigmoid_cross_entropy(multi_class_labels=tf.ones_like(real_values), logits=real_values, scope="discriminator_real_loss")
        discriminator_loss = tf.add(discriminator_real_loss, discriminator_fake_loss, name="discriminator_loss")
        tf.summary.scalar("discriminator_loss", discriminator_loss)
        
        lr = tf.train.exponential_decay(0.0002, tf.train.get_global_step(), 500, 0.95)
        tf.summary.scalar("learning_rate", lr)
        generator_optimizer = tf.train.AdamOptimizer(learning_rate=lr, beta1=0.5)
        discriminator_optimizer = tf.train.AdamOptimizer(learning_rate=lr, beta1=0.5)
        
        # for batch normalization, tell tensorflow update batch normalization mean and variance
        update_ops = tf.get_collection(tf.GraphKeys.UPDATE_OPS)
        with tf.control_dependencies(update_ops):
            discriminator_train_op = discriminator_optimizer.minimize(discriminator_loss, var_list=tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, scope="discriminator"))
            generator_train_op = generator_optimizer.minimize(generator_loss, var_list=tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, scope="generator"))
        
        step = tf.assign_add(tf.train.get_or_create_global_step(), 1)
        train_op = tf.group([discriminator_train_op, generator_train_op, step])
        
        # monitor trianing information
        logging_hook = tf.train.LoggingTensorHook({"generator_loss" : generator_loss,
                                                   "discriminator_loss" : discriminator_loss}, 
                                                  every_n_iter=SAVE_SUMMARY_STEPS)
        
        return tf.estimator.EstimatorSpec(mode, loss=generator_loss, train_op=train_op, training_hooks=[logging_hook])
    
    if mode == tf.estimator.ModeKeys.EVAL:
        tf.summary.image("fake_images", fake_images, max_outputs=10)
        eval_summary_hook = tf.train.SummarySaverHook(
                                save_steps=1,
                                output_dir=model_dir + "/eval_summary",
                                summary_op=tf.summary.merge_all())
        metrics = {"discriminator_fake_loss" : tf.metrics.mean(discriminator_fake_loss)}
        return tf.estimator.EstimatorSpec(mode, loss=generator_loss, eval_metric_ops=metrics, evaluation_hooks=[eval_summary_hook])

# %% [markdown]
# ## For Multiple GPU (Parallel Computing)
# Testing, not stable version
# Evaluation is not yet distributed

# %%
def get_distribution_strategy(num_gpus, all_reduce_alg=None):
    """Return a DistributionStrategy for running the model.
    Args:
    num_gpus: Number of GPUs to run this model.
    all_reduce_alg: Specify which algorithm to use when performing all-reduce.
      See tf.contrib.distribute.AllReduceCrossTowerOps for available algorithms.
      If None, DistributionStrategy will choose based on device topology.
    Returns:
    tf.contrib.distribute.DistibutionStrategy object.
    """
    if num_gpus == 0:
        return tf.contrib.distribute.OneDeviceStrategy("device:CPU:0")
    elif num_gpus == 1:
        return tf.contrib.distribute.OneDeviceStrategy("device:GPU:0")
    else:
        if all_reduce_alg:
            return tf.contrib.distribute.MirroredStrategy(
                num_gpus=num_gpus,
                cross_tower_ops=tf.contrib.distribute.AllReduceCrossTowerOps(
                    all_reduce_alg, num_packs=num_gpus))
        else:
            return tf.contrib.distribute.MirroredStrategy(num_gpus=num_gpus)

# %% [markdown]
# ## Set Runing Config

# %%
session_config = tf.ConfigProto()
session_config.gpu_options.per_process_gpu_memory_fraction = 0.8
session_config.gpu_options.allow_growth = True
config = tf.estimator.RunConfig(model_dir=model_dir, 
                                tf_random_seed=seed, 
                                save_summary_steps=SAVE_SUMMARY_STEPS, 
                                save_checkpoints_steps=SAVE_SUMMARY_STEPS, 
                                session_config=session_config,
                                keep_checkpoint_max=5, 
                                log_step_count_steps=SAVE_SUMMARY_STEPS, )
#                                train_distribute=get_distribution_strategy(NUM_GPUS)) #for mutiple GPUs
clf = tf.estimator.Estimator(model_fn=model_fn, model_dir=model_dir, config=config)
# Out:
# INFO:tensorflow:Using config: {'_model_dir': 'model_CGAN/', '_task_id': 0, '_num_ps_replicas': 0, '_service': None, '_task_type': 'worker', '_train_distribute': None, '_save_summary_steps': 50, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7fc409cd54e0>, '_keep_checkpoint_every_n_hours': 10000, '_num_worker_replicas': 1, '_evaluation_master': '', '_master': '', '_tf_random_seed': 2, '_save_checkpoints_steps': 50, '_global_id_in_cluster': 0, '_is_chief': True, '_log_step_count_steps': 50, '_device_fn': None, '_save_checkpoints_secs': None, '_session_config': gpu_options {
#   per_process_gpu_memory_fraction: 0.8
#   allow_growth: true
# }
# , '_keep_checkpoint_max': 5}

# %% [markdown]
# ## Train and Evaluate

# %%
train_spec = tf.estimator.TrainSpec(lambda:train_input_fn(image, label), max_steps=3000)
eval_spec = tf.estimator.EvalSpec(lambda:random_noise_input_fn(), throttle_secs=1)
tf.estimator.train_and_evaluate(clf, train_spec, eval_spec)
# Out:
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after every checkpoint. Checkpoint frequency is determined based on RunConfig arguments: save_checkpoints_steps 50 or save_checkpoints_secs None.
# output image: (?, 28, 28, 1)
# output label: (?, 1)
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into model_CGAN/model.ckpt.
# INFO:tensorflow:loss = 0.77881205, step = 1
# INFO:tensorflow:discriminator_loss = 1.4749471, generator_loss = 0.77881205
# INFO:tensorflow:Saving checkpoints for 50 into model_CGAN/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-20-03:53:55
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from model_CGAN/model.ckpt-50
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-20-03:53:55
# INFO:tensorflow:Saving dict for global step 50: discriminator_fake_loss = 0.416857, global_step = 50, loss = 1.1066257
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 50: model_CGAN/model.ckpt-50
# INFO:tensorflow:global_step/sec: 1.67337
# INFO:tensorflow:loss = 0.90552557, step = 50 (29.883 sec)
# INFO:tensorflow:discriminator_loss = 1.1144564, generator_loss = 0.90552557 (29.882 sec)
# INFO:tensorflow:Saving checkpoints for 100 into model_CGAN/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-20-03:54:18
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from model_CGAN/model.ckpt-100
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-20-03:54:18
# INFO:tensorflow:Saving dict for global step 100: discriminator_fake_loss = 0.39169455, global_step = 100, loss = 1.2258024
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 100: model_CGAN/model.ckpt-100
# INFO:tensorflow:global_step/sec: 2.54618
# INFO:tensorflow:loss = 1.0391482, step = 100 (19.636 sec)
# INFO:tensorflow:discriminator_loss = 1.090338, generator_loss = 1.0391482 (19.636 sec)
# INFO:tensorflow:Saving checkpoints for 150 into model_CGAN/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-20-03:54:37
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from model_CGAN/model.ckpt-150
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-20-03:54:37
# INFO:tensorflow:Saving dict for global step 150: discriminator_fake_loss = 0.67126936, global_step = 150, loss = 0.87443256
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 150: model_CGAN/model.ckpt-150
# INFO:tensorflow:global_step/sec: 2.62542
# INFO:tensorflow:loss = 1.0361884, step = 150 (19.045 sec)
# INFO:tensorflow:discriminator_loss = 1.1508331, generator_loss = 1.0361884 (19.046 sec)
# INFO:tensorflow:Saving checkpoints for 200 into model_CGAN/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-20-03:54:57
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from model_CGAN/model.ckpt-200
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-20-03:54:57
# INFO:tensorflow:Saving dict for global step 200: discriminator_fake_loss = 0.6811845, global_step = 200, loss = 0.7591714
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 200: model_CGAN/model.ckpt-200
# INFO:tensorflow:global_step/sec: 2.54452
# INFO:tensorflow:loss = 0.94274265, step = 200 (19.649 sec)
# INFO:tensorflow:discriminator_loss = 1.0256246, generator_loss = 0.94274265 (19.651 sec)
# INFO:tensorflow:Saving checkpoints for 250 into model_CGAN/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-20-03:55:16
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from model_CGAN/model.ckpt-250
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-20-03:55:16
# INFO:tensorflow:Saving dict for global step 250: discriminator_fake_loss = 0.49807897, global_step = 250, loss = 0.9620412
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 250: model_CGAN/model.ckpt-250
# INFO:tensorflow:global_step/sec: 2.5825
# INFO:tensorflow:loss = 0.92222, step = 250 (19.361 sec)
# INFO:tensorflow:discriminator_loss = 1.0118167, generator_loss = 0.92222 (19.360 sec)
# INFO:tensorflow:Saving checkpoints for 300 into model_CGAN/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-20-03:55:35
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from model_CGAN/model.ckpt-300
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-20-03:55:35
# INFO:tensorflow:Saving dict for global step 300: discriminator_fake_loss = 0.38582003, global_step = 300, loss = 1.3830556
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 300: model_CGAN/model.ckpt-300
# INFO:tensorflow:global_step/sec: 2.60348
# INFO:tensorflow:loss = 1.037539, step = 300 (19.206 sec)
# INFO:tensorflow:discriminator_loss = 1.1092818, generator_loss = 1.037539 (19.206 sec)
# INFO:tensorflow:Saving checkpoints for 350 into model_CGAN/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-20-03:55:53
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from model_CGAN/model.ckpt-350
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-20-03:55:53
# INFO:tensorflow:Saving dict for global step 350: discriminator_fake_loss = 0.48666364, global_step = 350, loss = 1.0099635
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 350: model_CGAN/model.ckpt-350
# INFO:tensorflow:global_step/sec: 2.78507
# INFO:tensorflow:loss = 1.0081432, step = 350 (17.954 sec)
# INFO:tensorflow:discriminator_loss = 1.0475075, generator_loss = 1.0081432 (17.954 sec)
# INFO:tensorflow:Saving checkpoints for 400 into model_CGAN/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-20-03:56:14
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from model_CGAN/model.ckpt-400
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-20-03:56:15
# INFO:tensorflow:Saving dict for global step 400: discriminator_fake_loss = 0.41944084, global_step = 400, loss = 1.1190246
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 400: model_CGAN/model.ckpt-400
# INFO:tensorflow:global_step/sec: 2.34717
# INFO:tensorflow:loss = 0.9481964, step = 400 (21.300 sec)
# INFO:tensorflow:discriminator_loss = 1.051206, generator_loss = 0.9481964 (21.301 sec)
# INFO:tensorflow:Saving checkpoints for 450 into model_CGAN/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-20-03:56:34
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from model_CGAN/model.ckpt-450
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-20-03:56:34
# INFO:tensorflow:Saving dict for global step 450: discriminator_fake_loss = 0.49761373, global_step = 450, loss = 1.0067911
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 450: model_CGAN/model.ckpt-450
# INFO:tensorflow:global_step/sec: 2.59632
# INFO:tensorflow:loss = 1.0020759, step = 450 (19.257 sec)
# INFO:tensorflow:discriminator_loss = 1.055211, generator_loss = 1.0020759 (19.258 sec)
# INFO:tensorflow:Saving checkpoints for 500 into model_CGAN/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-20-03:56:53
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from model_CGAN/model.ckpt-500
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-20-03:56:54
# INFO:tensorflow:Saving dict for global step 500: discriminator_fake_loss = 0.6589147, global_step = 500, loss = 0.92439806
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 500: model_CGAN/model.ckpt-500
# INFO:tensorflow:global_step/sec: 2.53805
# INFO:tensorflow:loss = 1.0395938, step = 500 (19.700 sec)
# INFO:tensorflow:discriminator_loss = 1.1286469, generator_loss = 1.0395938 (19.698 sec)
# INFO:tensorflow:Saving checkpoints for 550 into model_CGAN/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-20-03:57:13
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from model_CGAN/model.ckpt-550
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-20-03:57:13
# INFO:tensorflow:Saving dict for global step 550: discriminator_fake_loss = 0.736828, global_step = 550, loss = 0.7886173
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 550: model_CGAN/model.ckpt-550
# INFO:tensorflow:global_step/sec: 2.55849
# INFO:tensorflow:loss = 1.0202817, step = 550 (19.544 sec)
# INFO:tensorflow:discriminator_loss = 1.0728543, generator_loss = 1.0202817 (19.545 sec)
# INFO:tensorflow:Saving checkpoints for 600 into model_CGAN/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-20-03:57:32
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from model_CGAN/model.ckpt-600
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-20-03:57:33
# INFO:tensorflow:Saving dict for global step 600: discriminator_fake_loss = 0.54125315, global_step = 600, loss = 1.0146788
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 600: model_CGAN/model.ckpt-600
# INFO:tensorflow:global_step/sec: 2.582
# INFO:tensorflow:loss = 0.99533135, step = 600 (19.364 sec)
# INFO:tensorflow:discriminator_loss = 1.0692297, generator_loss = 0.99533135 (19.365 sec)
# INFO:tensorflow:Saving checkpoints for 650 into model_CGAN/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-20-03:57:52
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from model_CGAN/model.ckpt-650
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-20-03:57:52
# INFO:tensorflow:Saving dict for global step 650: discriminator_fake_loss = 0.42038694, global_step = 650, loss = 1.256863
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 650: model_CGAN/model.ckpt-650
# INFO:tensorflow:global_step/sec: 2.55825
# INFO:tensorflow:loss = 1.017569, step = 650 (19.544 sec)
# INFO:tensorflow:discriminator_loss = 1.1091881, generator_loss = 1.017569 (19.545 sec)
# INFO:tensorflow:Saving checkpoints for 700 into model_CGAN/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-20-03:58:10
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from model_CGAN/model.ckpt-700
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-20-03:58:11
# INFO:tensorflow:Saving dict for global step 700: discriminator_fake_loss = 0.34582737, global_step = 700, loss = 1.4988111
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 700: model_CGAN/model.ckpt-700
# INFO:tensorflow:global_step/sec: 2.69141
# INFO:tensorflow:loss = 1.0313158, step = 700 (18.580 sec)
# INFO:tensorflow:discriminator_loss = 1.1495516, generator_loss = 1.0313158 (18.578 sec)
# INFO:tensorflow:Saving checkpoints for 750 into model_CGAN/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-20-03:58:31
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from model_CGAN/model.ckpt-750
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-20-03:58:32
# INFO:tensorflow:Saving dict for global step 750: discriminator_fake_loss = 0.56389517, global_step = 750, loss = 0.9933961
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 750: model_CGAN/model.ckpt-750
# INFO:tensorflow:global_step/sec: 2.37835
# INFO:tensorflow:loss = 0.9720412, step = 750 (21.022 sec)
# INFO:tensorflow:discriminator_loss = 1.0931914, generator_loss = 0.9720412 (21.023 sec)
# INFO:tensorflow:Saving checkpoints for 800 into model_CGAN/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-20-03:58:51
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from model_CGAN/model.ckpt-800
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-20-03:58:51
# INFO:tensorflow:Saving dict for global step 800: discriminator_fake_loss = 0.6662095, global_step = 800, loss = 0.76035815
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 800: model_CGAN/model.ckpt-800
# INFO:tensorflow:global_step/sec: 2.55125
# INFO:tensorflow:loss = 0.97691464, step = 800 (19.599 sec)
# INFO:tensorflow:discriminator_loss = 1.0467615, generator_loss = 0.97691464 (19.598 sec)
# INFO:tensorflow:Saving checkpoints for 850 into model_CGAN/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-20-03:59:11
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from model_CGAN/model.ckpt-850
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-20-03:59:11
# INFO:tensorflow:Saving dict for global step 850: discriminator_fake_loss = 0.57585657, global_step = 850, loss = 0.874918
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 850: model_CGAN/model.ckpt-850
# INFO:tensorflow:global_step/sec: 2.50081
# INFO:tensorflow:loss = 0.93782127, step = 850 (19.992 sec)
# INFO:tensorflow:discriminator_loss = 1.0397911, generator_loss = 0.93782127 (19.992 sec)
# INFO:tensorflow:Saving checkpoints for 900 into model_CGAN/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-20-03:59:31
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from model_CGAN/model.ckpt-900
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-20-03:59:31
# INFO:tensorflow:Saving dict for global step 900: discriminator_fake_loss = 1.0714152, global_step = 900, loss = 0.52646184
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 900: model_CGAN/model.ckpt-900
# INFO:tensorflow:global_step/sec: 2.53481
# INFO:tensorflow:loss = 0.79941857, step = 900 (19.726 sec)
# INFO:tensorflow:discriminator_loss = 1.2411721, generator_loss = 0.79941857 (19.727 sec)
# INFO:tensorflow:Saving checkpoints for 950 into model_CGAN/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-20-03:59:50
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from model_CGAN/model.ckpt-950
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-20-03:59:50
# INFO:tensorflow:Saving dict for global step 950: discriminator_fake_loss = 0.42541814, global_step = 950, loss = 1.2381089
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 950: model_CGAN/model.ckpt-950
# INFO:tensorflow:global_step/sec: 2.56305
# INFO:tensorflow:loss = 0.9756576, step = 950 (19.509 sec)
# INFO:tensorflow:discriminator_loss = 1.1294887, generator_loss = 0.9756576 (19.507 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into model_CGAN/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-20-04:00:10
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from model_CGAN/model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-20-04:00:11
# INFO:tensorflow:Saving dict for global step 1000: discriminator_fake_loss = 0.63372344, global_step = 1000, loss = 1.0735551
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1000: model_CGAN/model.ckpt-1000
# INFO:tensorflow:global_step/sec: 2.485
# INFO:tensorflow:loss = 1.1000602, step = 1000 (20.121 sec)
# INFO:tensorflow:discriminator_loss = 1.142225, generator_loss = 1.1000602 (20.122 sec)
# INFO:tensorflow:Saving checkpoints for 1050 into model_CGAN/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-20-04:00:30
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from model_CGAN/model.ckpt-1050
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-20-04:00:30
# INFO:tensorflow:Saving dict for global step 1050: discriminator_fake_loss = 0.45714518, global_step = 1050, loss = 1.0325742
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1050: model_CGAN/model.ckpt-1050
# INFO:tensorflow:global_step/sec: 2.59199
# INFO:tensorflow:loss = 0.8329489, step = 1050 (19.290 sec)
# INFO:tensorflow:discriminator_loss = 1.1154652, generator_loss = 0.8329489 (19.288 sec)
# INFO:tensorflow:Saving checkpoints for 1100 into model_CGAN/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-20-04:00:51
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from model_CGAN/model.ckpt-1100
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-20-04:00:51
# INFO:tensorflow:Saving dict for global step 1100: discriminator_fake_loss = 0.3850231, global_step = 1100, loss = 1.2522444
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1100: model_CGAN/model.ckpt-1100
# INFO:tensorflow:global_step/sec: 2.36534
# INFO:tensorflow:loss = 0.96123636, step = 1100 (21.138 sec)
# INFO:tensorflow:discriminator_loss = 1.123743, generator_loss = 0.96123636 (21.139 sec)
# INFO:tensorflow:Saving checkpoints for 1150 into model_CGAN/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-20-04:01:10
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from model_CGAN/model.ckpt-1150
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-20-04:01:11
# INFO:tensorflow:Saving dict for global step 1150: discriminator_fake_loss = 0.6226895, global_step = 1150, loss = 0.8443594
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1150: model_CGAN/model.ckpt-1150
# INFO:tensorflow:global_step/sec: 2.52447
# INFO:tensorflow:loss = 0.9266768, step = 1150 (19.807 sec)
# INFO:tensorflow:discriminator_loss = 1.0739944, generator_loss = 0.9266768 (19.807 sec)
# INFO:tensorflow:Saving checkpoints for 1200 into model_CGAN/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-20-04:01:30
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from model_CGAN/model.ckpt-1200
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-20-04:01:31
# INFO:tensorflow:Saving dict for global step 1200: discriminator_fake_loss = 0.5441224, global_step = 1200, loss = 0.9097597
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1200: model_CGAN/model.ckpt-1200
# INFO:tensorflow:global_step/sec: 2.52887
# INFO:tensorflow:loss = 1.0666293, step = 1200 (19.771 sec)
# INFO:tensorflow:discriminator_loss = 1.0259199, generator_loss = 1.0666293 (19.770 sec)
# INFO:tensorflow:Saving checkpoints for 1250 into model_CGAN/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-20-04:01:50
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from model_CGAN/model.ckpt-1250
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-20-04:01:50
# INFO:tensorflow:Saving dict for global step 1250: discriminator_fake_loss = 1.2325171, global_step = 1250, loss = 0.5930783
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1250: model_CGAN/model.ckpt-1250
# INFO:tensorflow:global_step/sec: 2.54224
# INFO:tensorflow:loss = 0.93095404, step = 1250 (19.669 sec)
# INFO:tensorflow:discriminator_loss = 1.2240099, generator_loss = 0.93095404 (19.668 sec)
# INFO:tensorflow:Saving checkpoints for 1300 into model_CGAN/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-20-04:02:09
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from model_CGAN/model.ckpt-1300
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-20-04:02:10
# INFO:tensorflow:Saving dict for global step 1300: discriminator_fake_loss = 0.61556906, global_step = 1300, loss = 0.8806187
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1300: model_CGAN/model.ckpt-1300
# INFO:tensorflow:global_step/sec: 2.55582
# INFO:tensorflow:loss = 0.99211854, step = 1300 (19.563 sec)
# INFO:tensorflow:discriminator_loss = 1.1215852, generator_loss = 0.99211854 (19.563 sec)
# INFO:tensorflow:Saving checkpoints for 1350 into model_CGAN/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-20-04:02:29
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from model_CGAN/model.ckpt-1350
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-20-04:02:29
# INFO:tensorflow:Saving dict for global step 1350: discriminator_fake_loss = 0.23313022, global_step = 1350, loss = 1.6705745
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1350: model_CGAN/model.ckpt-1350
# INFO:tensorflow:global_step/sec: 2.57882
# INFO:tensorflow:loss = 1.0985303, step = 1350 (19.388 sec)
# INFO:tensorflow:discriminator_loss = 1.0141294, generator_loss = 1.0985303 (19.387 sec)
# INFO:tensorflow:Saving checkpoints for 1400 into model_CGAN/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-20-04:02:48
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from model_CGAN/model.ckpt-1400
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-20-04:02:48
# INFO:tensorflow:Saving dict for global step 1400: discriminator_fake_loss = 0.3722676, global_step = 1400, loss = 1.2520202
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1400: model_CGAN/model.ckpt-1400
# INFO:tensorflow:global_step/sec: 2.60254
# INFO:tensorflow:loss = 1.0284486, step = 1400 (19.214 sec)
# INFO:tensorflow:discriminator_loss = 1.0097052, generator_loss = 1.0284486 (19.215 sec)
# INFO:tensorflow:Saving checkpoints for 1450 into model_CGAN/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-20-04:03:09
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from model_CGAN/model.ckpt-1450
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-20-04:03:09
# INFO:tensorflow:Saving dict for global step 1450: discriminator_fake_loss = 0.43384725, global_step = 1450, loss = 1.0640638
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1450: model_CGAN/model.ckpt-1450
# INFO:tensorflow:global_step/sec: 2.42456
# INFO:tensorflow:loss = 1.0596015, step = 1450 (20.620 sec)
# INFO:tensorflow:discriminator_loss = 1.0011233, generator_loss = 1.0596015 (20.619 sec)
# INFO:tensorflow:Saving checkpoints for 1500 into model_CGAN/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-20-04:03:28
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from model_CGAN/model.ckpt-1500
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-20-04:03:28
# INFO:tensorflow:Saving dict for global step 1500: discriminator_fake_loss = 0.5669235, global_step = 1500, loss = 0.96533793
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1500: model_CGAN/model.ckpt-1500
# INFO:tensorflow:global_step/sec: 2.59427
# INFO:tensorflow:loss = 0.96426713, step = 1500 (19.275 sec)
# INFO:tensorflow:discriminator_loss = 1.0950673, generator_loss = 0.96426713 (19.275 sec)
# INFO:tensorflow:Saving checkpoints for 1550 into model_CGAN/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-20-04:03:48
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from model_CGAN/model.ckpt-1550
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-20-04:03:48
# INFO:tensorflow:Saving dict for global step 1550: discriminator_fake_loss = 0.43441007, global_step = 1550, loss = 1.1981194
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1550: model_CGAN/model.ckpt-1550
# INFO:tensorflow:global_step/sec: 2.54467
# INFO:tensorflow:loss = 1.108639, step = 1550 (19.648 sec)
# INFO:tensorflow:discriminator_loss = 1.1001929, generator_loss = 1.108639 (19.650 sec)
# INFO:tensorflow:Saving checkpoints for 1600 into model_CGAN/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-20-04:04:07
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from model_CGAN/model.ckpt-1600
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-20-04:04:08
# INFO:tensorflow:Saving dict for global step 1600: discriminator_fake_loss = 0.4556841, global_step = 1600, loss = 1.1399616
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1600: model_CGAN/model.ckpt-1600
# INFO:tensorflow:global_step/sec: 2.53531
# INFO:tensorflow:loss = 1.0172467, step = 1600 (19.721 sec)
# INFO:tensorflow:discriminator_loss = 1.0429739, generator_loss = 1.0172467 (19.721 sec)
# INFO:tensorflow:Saving checkpoints for 1650 into model_CGAN/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-20-04:04:27
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from model_CGAN/model.ckpt-1650
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-20-04:04:27
# INFO:tensorflow:Saving dict for global step 1650: discriminator_fake_loss = 0.27060276, global_step = 1650, loss = 1.5246447
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1650: model_CGAN/model.ckpt-1650
# INFO:tensorflow:global_step/sec: 2.53558
# INFO:tensorflow:loss = 1.0300539, step = 1650 (19.721 sec)
# INFO:tensorflow:discriminator_loss = 1.0002124, generator_loss = 1.0300539 (19.720 sec)
# INFO:tensorflow:Saving checkpoints for 1700 into model_CGAN/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-20-04:04:47
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from model_CGAN/model.ckpt-1700
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-20-04:04:47
# INFO:tensorflow:Saving dict for global step 1700: discriminator_fake_loss = 0.6226839, global_step = 1700, loss = 0.8285179
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1700: model_CGAN/model.ckpt-1700
# INFO:tensorflow:global_step/sec: 2.52549
# INFO:tensorflow:loss = 0.96299535, step = 1700 (19.798 sec)
# INFO:tensorflow:discriminator_loss = 1.0972066, generator_loss = 0.96299535 (19.798 sec)
# INFO:tensorflow:Saving checkpoints for 1750 into model_CGAN/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-20-04:05:06
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from model_CGAN/model.ckpt-1750
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-20-04:05:07
# INFO:tensorflow:Saving dict for global step 1750: discriminator_fake_loss = 0.49207258, global_step = 1750, loss = 1.1112207
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1750: model_CGAN/model.ckpt-1750
# INFO:tensorflow:global_step/sec: 2.56604
# INFO:tensorflow:loss = 0.982773, step = 1750 (19.485 sec)
# INFO:tensorflow:discriminator_loss = 1.0163224, generator_loss = 0.982773 (19.486 sec)
# INFO:tensorflow:Saving checkpoints for 1800 into model_CGAN/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-20-04:05:27
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from model_CGAN/model.ckpt-1800
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-20-04:05:27
# INFO:tensorflow:Saving dict for global step 1800: discriminator_fake_loss = 0.35601208, global_step = 1800, loss = 1.2563515
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1800: model_CGAN/model.ckpt-1800
# INFO:tensorflow:global_step/sec: 2.46455
# INFO:tensorflow:loss = 1.0348932, step = 1800 (20.289 sec)
# INFO:tensorflow:discriminator_loss = 0.9997523, generator_loss = 1.0348932 (20.288 sec)
# INFO:tensorflow:Saving checkpoints for 1850 into model_CGAN/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-20-04:05:46
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from model_CGAN/model.ckpt-1850
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-20-04:05:46
# INFO:tensorflow:Saving dict for global step 1850: discriminator_fake_loss = 0.89363, global_step = 1850, loss = 0.58579344
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1850: model_CGAN/model.ckpt-1850
# INFO:tensorflow:global_step/sec: 2.56999
# INFO:tensorflow:loss = 0.7892506, step = 1850 (19.453 sec)
# INFO:tensorflow:discriminator_loss = 1.2947462, generator_loss = 0.7892506 (19.455 sec)
# INFO:tensorflow:Saving checkpoints for 1900 into model_CGAN/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-20-04:06:06
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from model_CGAN/model.ckpt-1900
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-20-04:06:06
# INFO:tensorflow:Saving dict for global step 1900: discriminator_fake_loss = 0.3484399, global_step = 1900, loss = 1.2784628
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1900: model_CGAN/model.ckpt-1900
# INFO:tensorflow:global_step/sec: 2.55689
# INFO:tensorflow:loss = 0.97572714, step = 1900 (19.556 sec)
# INFO:tensorflow:discriminator_loss = 1.027751, generator_loss = 0.97572714 (19.554 sec)
# INFO:tensorflow:Saving checkpoints for 1950 into model_CGAN/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-20-04:06:25
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from model_CGAN/model.ckpt-1950
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-20-04:06:26
# INFO:tensorflow:Saving dict for global step 1950: discriminator_fake_loss = 0.38847727, global_step = 1950, loss = 1.346613
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 1950: model_CGAN/model.ckpt-1950
# INFO:tensorflow:global_step/sec: 2.53865
# INFO:tensorflow:loss = 0.9557383, step = 1950 (19.697 sec)
# INFO:tensorflow:discriminator_loss = 1.1698236, generator_loss = 0.9557383 (19.698 sec)
# INFO:tensorflow:Saving checkpoints for 2000 into model_CGAN/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-20-04:06:45
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from model_CGAN/model.ckpt-2000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-20-04:06:45
# INFO:tensorflow:Saving dict for global step 2000: discriminator_fake_loss = 0.4769846, global_step = 2000, loss = 1.0555412
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 2000: model_CGAN/model.ckpt-2000
# INFO:tensorflow:global_step/sec: 2.55197
# INFO:tensorflow:loss = 0.96679866, step = 2000 (19.591 sec)
# INFO:tensorflow:discriminator_loss = 1.037113, generator_loss = 0.96679866 (19.590 sec)
# INFO:tensorflow:Saving checkpoints for 2050 into model_CGAN/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-20-04:07:03
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from model_CGAN/model.ckpt-2050
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-20-04:07:04
# INFO:tensorflow:Saving dict for global step 2050: discriminator_fake_loss = 0.5662827, global_step = 2050, loss = 0.8956671
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 2050: model_CGAN/model.ckpt-2050
# INFO:tensorflow:global_step/sec: 2.52514
# INFO:tensorflow:loss = 1.15464, step = 2050 (19.803 sec)
# INFO:tensorflow:discriminator_loss = 0.994027, generator_loss = 1.15464 (19.803 sec)
# INFO:tensorflow:Saving checkpoints for 2100 into model_CGAN/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-20-04:07:25
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from model_CGAN/model.ckpt-2100
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-20-04:07:25
# INFO:tensorflow:Saving dict for global step 2100: discriminator_fake_loss = 0.56961316, global_step = 2100, loss = 1.8970383
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 2100: model_CGAN/model.ckpt-2100
# INFO:tensorflow:global_step/sec: 2.52511
# INFO:tensorflow:loss = 0.6998372, step = 2100 (19.801 sec)
# INFO:tensorflow:discriminator_loss = 1.3770981, generator_loss = 0.6998372 (19.799 sec)
# INFO:tensorflow:Saving checkpoints for 2150 into model_CGAN/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-20-04:07:44
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from model_CGAN/model.ckpt-2150
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-20-04:07:45
# INFO:tensorflow:Saving dict for global step 2150: discriminator_fake_loss = 0.55114764, global_step = 2150, loss = 0.96675533
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 2150: model_CGAN/model.ckpt-2150
# INFO:tensorflow:global_step/sec: 2.53054
# INFO:tensorflow:loss = 0.70317954, step = 2150 (19.759 sec)
# INFO:tensorflow:discriminator_loss = 1.3601637, generator_loss = 0.70317954 (19.760 sec)
# INFO:tensorflow:Saving checkpoints for 2200 into model_CGAN/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-20-04:08:04
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from model_CGAN/model.ckpt-2200
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-20-04:08:04
# INFO:tensorflow:Saving dict for global step 2200: discriminator_fake_loss = 0.58952343, global_step = 2200, loss = 0.8471417
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 2200: model_CGAN/model.ckpt-2200
# INFO:tensorflow:global_step/sec: 2.55546
# INFO:tensorflow:loss = 0.7338683, step = 2201 (19.565 sec)
# INFO:tensorflow:discriminator_loss = 1.3341627, generator_loss = 0.7338683 (19.566 sec)
# INFO:tensorflow:Saving checkpoints for 2250 into model_CGAN/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-20-04:08:23
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from model_CGAN/model.ckpt-2250
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-20-04:08:23
# INFO:tensorflow:Saving dict for global step 2250: discriminator_fake_loss = 0.5386271, global_step = 2250, loss = 0.922146
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 2250: model_CGAN/model.ckpt-2250
# INFO:tensorflow:global_step/sec: 2.60551
# INFO:tensorflow:loss = 0.780215, step = 2250 (19.190 sec)
# INFO:tensorflow:discriminator_loss = 1.2808499, generator_loss = 0.780215 (19.189 sec)
# INFO:tensorflow:Saving checkpoints for 2300 into model_CGAN/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-20-04:08:43
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from model_CGAN/model.ckpt-2300
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-20-04:08:43
# INFO:tensorflow:Saving dict for global step 2300: discriminator_fake_loss = 0.75397867, global_step = 2300, loss = 0.77501756
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 2300: model_CGAN/model.ckpt-2300
# INFO:tensorflow:global_step/sec: 2.57468
# INFO:tensorflow:loss = 0.79480493, step = 2300 (19.421 sec)
# INFO:tensorflow:discriminator_loss = 1.2509224, generator_loss = 0.79480493 (19.421 sec)
# INFO:tensorflow:Saving checkpoints for 2350 into model_CGAN/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-20-04:09:02
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from model_CGAN/model.ckpt-2350
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-20-04:09:02
# INFO:tensorflow:Saving dict for global step 2350: discriminator_fake_loss = 0.8579748, global_step = 2350, loss = 0.78280103
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 2350: model_CGAN/model.ckpt-2350
# INFO:tensorflow:global_step/sec: 2.56577
# INFO:tensorflow:loss = 0.9381983, step = 2350 (19.486 sec)
# INFO:tensorflow:discriminator_loss = 1.1495329, generator_loss = 0.9381983 (19.486 sec)
# INFO:tensorflow:Saving checkpoints for 2400 into model_CGAN/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-20-04:09:20
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from model_CGAN/model.ckpt-2400
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-20-04:09:20
# INFO:tensorflow:Saving dict for global step 2400: discriminator_fake_loss = 0.6429272, global_step = 2400, loss = 0.84045506
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 2400: model_CGAN/model.ckpt-2400
# INFO:tensorflow:global_step/sec: 2.77552
# INFO:tensorflow:loss = 0.9837883, step = 2400 (18.016 sec)
# INFO:tensorflow:discriminator_loss = 1.1650126, generator_loss = 0.9837883 (18.014 sec)
# INFO:tensorflow:Saving checkpoints for 2450 into model_CGAN/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-20-04:09:41
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from model_CGAN/model.ckpt-2450
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-20-04:09:41
# INFO:tensorflow:Saving dict for global step 2450: discriminator_fake_loss = 0.8632812, global_step = 2450, loss = 0.6843467
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 2450: model_CGAN/model.ckpt-2450
# INFO:tensorflow:global_step/sec: 2.37481
# INFO:tensorflow:loss = 0.94491893, step = 2450 (21.055 sec)
# INFO:tensorflow:discriminator_loss = 1.0553356, generator_loss = 0.94491893 (21.056 sec)
# INFO:tensorflow:Saving checkpoints for 2500 into model_CGAN/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-20-04:10:01
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from model_CGAN/model.ckpt-2500
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-20-04:10:01
# INFO:tensorflow:Saving dict for global step 2500: discriminator_fake_loss = 0.63545257, global_step = 2500, loss = 0.87167865
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 2500: model_CGAN/model.ckpt-2500
# INFO:tensorflow:global_step/sec: 2.54491
# INFO:tensorflow:loss = 1.0615215, step = 2500 (19.646 sec)
# INFO:tensorflow:discriminator_loss = 1.0759712, generator_loss = 1.0615215 (19.647 sec)
# INFO:tensorflow:Saving checkpoints for 2550 into model_CGAN/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-20-04:10:20
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from model_CGAN/model.ckpt-2550
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-20-04:10:20
# INFO:tensorflow:Saving dict for global step 2550: discriminator_fake_loss = 0.82645035, global_step = 2550, loss = 0.6346533
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 2550: model_CGAN/model.ckpt-2550
# INFO:tensorflow:global_step/sec: 2.5796
# INFO:tensorflow:loss = 0.99757874, step = 2550 (19.381 sec)
# INFO:tensorflow:discriminator_loss = 1.0218753, generator_loss = 0.99757874 (19.380 sec)
# INFO:tensorflow:Saving checkpoints for 2600 into model_CGAN/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-20-04:10:39
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from model_CGAN/model.ckpt-2600
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-20-04:10:40
# INFO:tensorflow:Saving dict for global step 2600: discriminator_fake_loss = 1.216077, global_step = 2600, loss = 0.509683
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 2600: model_CGAN/model.ckpt-2600
# INFO:tensorflow:global_step/sec: 2.5787
# INFO:tensorflow:loss = 0.9035861, step = 2600 (19.391 sec)
# INFO:tensorflow:discriminator_loss = 1.095824, generator_loss = 0.9035861 (19.392 sec)
# INFO:tensorflow:Saving checkpoints for 2650 into model_CGAN/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-20-04:10:59
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from model_CGAN/model.ckpt-2650
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-20-04:10:59
# INFO:tensorflow:Saving dict for global step 2650: discriminator_fake_loss = 0.52145666, global_step = 2650, loss = 0.967411
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 2650: model_CGAN/model.ckpt-2650
# INFO:tensorflow:global_step/sec: 2.59139
# INFO:tensorflow:loss = 0.8767143, step = 2650 (19.295 sec)
# INFO:tensorflow:discriminator_loss = 1.0890355, generator_loss = 0.8767143 (19.294 sec)
# INFO:tensorflow:Saving checkpoints for 2700 into model_CGAN/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-20-04:11:18
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from model_CGAN/model.ckpt-2700
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-20-04:11:18
# INFO:tensorflow:Saving dict for global step 2700: discriminator_fake_loss = 0.75878644, global_step = 2700, loss = 0.7934372
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 2700: model_CGAN/model.ckpt-2700
# INFO:tensorflow:global_step/sec: 2.5902
# INFO:tensorflow:loss = 1.1260248, step = 2700 (19.304 sec)
# INFO:tensorflow:discriminator_loss = 1.0632474, generator_loss = 1.1260248 (19.304 sec)
# INFO:tensorflow:Saving checkpoints for 2750 into model_CGAN/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-20-04:11:37
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from model_CGAN/model.ckpt-2750
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-20-04:11:37
# INFO:tensorflow:Saving dict for global step 2750: discriminator_fake_loss = 0.43060574, global_step = 2750, loss = 1.3111871
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 2750: model_CGAN/model.ckpt-2750
# INFO:tensorflow:global_step/sec: 2.66561
# INFO:tensorflow:loss = 1.0675162, step = 2750 (18.757 sec)
# INFO:tensorflow:discriminator_loss = 1.0718906, generator_loss = 1.0675162 (18.756 sec)
# INFO:tensorflow:Saving checkpoints for 2800 into model_CGAN/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-20-04:11:58
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from model_CGAN/model.ckpt-2800
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-20-04:11:58
# INFO:tensorflow:Saving dict for global step 2800: discriminator_fake_loss = 0.9333052, global_step = 2800, loss = 0.5217735
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 2800: model_CGAN/model.ckpt-2800
# INFO:tensorflow:global_step/sec: 2.39068
# INFO:tensorflow:loss = 0.72605413, step = 2800 (20.915 sec)
# INFO:tensorflow:discriminator_loss = 1.358675, generator_loss = 0.72605413 (20.916 sec)
# INFO:tensorflow:Saving checkpoints for 2850 into model_CGAN/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-20-04:12:17
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from model_CGAN/model.ckpt-2850
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-20-04:12:18
# INFO:tensorflow:Saving dict for global step 2850: discriminator_fake_loss = 0.74885213, global_step = 2850, loss = 0.71950316
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 2850: model_CGAN/model.ckpt-2850
# INFO:tensorflow:global_step/sec: 2.57408
# INFO:tensorflow:loss = 0.7406676, step = 2850 (19.425 sec)
# INFO:tensorflow:discriminator_loss = 1.3227646, generator_loss = 0.7406676 (19.425 sec)
# INFO:tensorflow:Saving checkpoints for 2900 into model_CGAN/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-20-04:12:37
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from model_CGAN/model.ckpt-2900
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-20-04:12:37
# INFO:tensorflow:Saving dict for global step 2900: discriminator_fake_loss = 0.6325839, global_step = 2900, loss = 0.7687257
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 2900: model_CGAN/model.ckpt-2900
# INFO:tensorflow:global_step/sec: 2.54253
# INFO:tensorflow:loss = 0.78559744, step = 2900 (19.665 sec)
# INFO:tensorflow:discriminator_loss = 1.3101122, generator_loss = 0.78559744 (19.666 sec)
# INFO:tensorflow:Saving checkpoints for 2930 into model_CGAN/model.ckpt.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-09-20-04:12:46
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from model_CGAN/model.ckpt-2930
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-09-20-04:12:47
# INFO:tensorflow:Saving dict for global step 2930: discriminator_fake_loss = 0.6973801, global_step = 2930, loss = 0.70113486
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 2930: model_CGAN/model.ckpt-2930
# INFO:tensorflow:Loss for final step: 0.7934388.
# ({'discriminator_fake_loss': 0.6973801,
#   'global_step': 2930,
#   'loss': 0.70113486},
#  [])

# %% [markdown]
# ## Save model for Tensorflow Serving
# Can not save model after **predict**, because `Graph` is finalized and cannot be modified
# You can assign which model to be saved by `checkpoint_path` parameter

# %%
# input
vector = tf.placeholder(tf.float32, shape=[None, NOISE_DIM], name='random_noises')
label = tf.placeholder(tf.float32, shape=[None, 1], name="labels")
# input receiver
input_fn = tf.estimator.export.build_raw_serving_input_receiver_fn({
    'random_noises': vector,
    'labels': label
})

clf.export_savedmodel("saved_model/", input_fn, checkpoint_path="model_CGAN/model.ckpt-2930")
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Signatures INCLUDED in export for Train: None
# INFO:tensorflow:Signatures INCLUDED in export for Classify: None
# INFO:tensorflow:Signatures INCLUDED in export for Predict: ['serving_default', 'output']
# INFO:tensorflow:Signatures INCLUDED in export for Regress: None
# INFO:tensorflow:Signatures INCLUDED in export for Eval: None
# INFO:tensorflow:Restoring parameters from model_CGAN/model.ckpt-2930
# INFO:tensorflow:Assets added to graph.
# INFO:tensorflow:No assets to write.
# INFO:tensorflow:SavedModel written to: saved_model/temp-b'1537419973'/saved_model.pb
# b'saved_model/1537419973'

# %% [markdown]
# ## Load model and predict
# Estimator predict method return **generator** type, so if you want to get all predictions please use for loop
# ```python
# for result in results:
#     print(result)
# ```

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
results = clf.predict(lambda: random_noise_input_fn(), checkpoint_path="model_CGAN/model.ckpt-2930")
for result in results:
    plt.imshow(result["images"][:,:,0])
    break
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from model_CGAN/model.ckpt-2930
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.

# %% [markdown]
# ## Load model from `Estimator.export_savedmodel`
# Reference: https://qiita.com/parkkiung123/items/13adb482860f356f97f3

# %%
import tensorflow as tf
import numpy as np

export_dir = 'saved_model/1537419973'

with tf.Session(graph=tf.Graph()) as sess:
    # saved_model load
    tf.saved_model.loader.load(sess, [tf.saved_model.tag_constants.SERVING], export_dir)
    # print all tensor name
#     for op in sess.graph.get_operations():
#         print(op.values())
    # input
    i = sess.graph.get_tensor_by_name("random_noises:0")
    label = sess.graph.get_tensor_by_name("labels:0")
    # output
    r = sess.graph.get_tensor_by_name("generator/output/tanh:0")
    image = sess.run(r, feed_dict={i:np.random.randn(1, NOISE_DIM), label:[[1.0]]})
    print(image.shape)
    plt.imshow(image[0][:,:,0])
# Out:
# INFO:tensorflow:Restoring parameters from saved_model/1537419973/variables/variables
# (1, 28, 28, 1)
